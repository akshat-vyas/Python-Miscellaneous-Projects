# %% [markdown]
# # Question Bank (100 Questions)

# %% [markdown]
# # Topics Covered

# %%
# importing libraries
import pandas as pd
import numpy as np
from datetime import datetime
from IPython.display import display

# %%
df=pd.read_csv("Retail_Sales_Data1.csv")

# %%
df.head(10)
# df.sample(10)
# Out:
#    Transaction_ID     Transaction_Time  Product_ID     Category  Quantity  \
# 0               1  2023-01-01 00:00:00         132    Furniture         5
# 1               2  2023-01-01 01:00:00         131       Sports         1
# 2               3  2023-01-01 02:00:00         127       Sports         1
# 3               4  2023-01-01 03:00:00         114  Electronics         8
# 4               5  2023-01-01 04:00:00         119  Electronics         2
# 5               6  2023-01-01 05:00:00         128     Clothing         6
# 6               7  2023-01-01 06:00:00         138    Furniture         7
# 7               8  2023-01-01 07:00:00         130    Furniture        10
# 8               9  2023-01-01 08:00:00         108        Books         5
# 9              10  2023-01-01 09:00:00         108    Furniture         8
#
#    Unit_Price  Total_Sales  Customer_ID  Payment_Method  Discount
# 0       17.73        88.65         1075     Credit Card      2.82
# ...

# %% [markdown]
# # **Basic Data Exploration**

# %% [markdown]
# # 1. How many total transactions are in the dataset?

# %%
df["Transaction_ID"].nunique()
# Out:
# 300

# %% [markdown]
# # 2. What are the unique product categories in the dataset?

# %%
df["Category"].unique()
# Out:
# array(['Furniture', 'Sports', 'Electronics', 'Clothing', 'Books'],
#       dtype=object)

# %% [markdown]
# # 3. How many transactions involve "Furniture" products?

# %%
df[df["Category"]=="Furniture"].shape[0]
# Out:
# 91

# %% [markdown]
# # 4. What is the average unit price for "Electronics" products?

# %%
df[df["Category"]=="Electronics"]["Unit_Price"].mean()
# Out:
# 83.569

# %% [markdown]
# # 5. How many transactions were paid with credit card?

# %%
df[df["Payment_Method"]=="Credit Card"].shape[0]
# Out:
# 98

# %% [markdown]
# # 6. What is the most common payment method?

# %%
df['Payment_Method'].describe().top
# df["Payment_Method"].mode()
# Out:
# 'Credit Card'

# %% [markdown]
# # 7. What are the unique payment methods in the dataset?

# %%
df["Payment_Method"].unique()
# Out:
# array(['Credit Card', 'Debit Card', 'Online Payment', 'Cash'],
#       dtype=object)

# %% [markdown]
# # 8. What is the average total sales for "Sports" products?

# %%
df[df["Category"]=="Sports"]["Total_Sales"].mean()
# Out:
# 315.0966666666667

# %% [markdown]
# # 9. What is the mean discount across all transactions?

# %%
df["Discount"].mean()
# Out:
# 7.128

# %% [markdown]
# # 10. How many transactions were made by customer ID 1001?

# %%
df[df["Customer_ID"]==1001].shape[0]
# Out:
# 2

# %% [markdown]
# # 11.  Which product had the highest total sales?

# %%
df[df["Total_Sales"]==df["Total_Sales"].max()]["Category"]
# df["Total_Sales"].max()
# Out:
# 249    Electronics
# Name: Category, dtype: object

# %% [markdown]
# # 12.  How many unique customer IDs are there in the dataset?

# %%
df["Customer_ID"].nunique()
# Out:
# 96

# %% [markdown]
# # 13. What is the total sales value for the first day in the dataset?

# %%
df[df["Transaction_Time"]==df["Transaction_Time"].sort_values()[0]]
# Out:
#    Transaction_ID     Transaction_Time  Product_ID   Category  Quantity  \
# 0               1  2023-01-01 00:00:00         132  Furniture         5
#
#    Unit_Price  Total_Sales  Customer_ID Payment_Method  Discount
# 0       17.73        88.65         1075    Credit Card      2.82

# %% [markdown]
# # 14. What is the maximum discount given in any transaction?

# %%
df["Discount"].max()
# Out:
# 14.55

# %% [markdown]
# # 15. How many unique transaction times are in the dataset?

# %%
df["Transaction_Time"].nunique()
# Out:
# 300

# %% [markdown]
# # **Data Aggregation and Grouping**

# %% [markdown]
# # 16. What is the total quantity of products sold for each category?

# %%
df.groupby("Category")["Quantity"].sum()
# Out:
# Category
# Books          699
# Clothing       113
# Electronics    216
# Furniture      484
# Sports         152
# Name: Quantity, dtype: int64

# %% [markdown]
# # 17. What is the total sales value for each category?

# %%
df.groupby("Category")["Total_Sales"].sum()
# Out:
# Category
# Books          57481.22
# Clothing        7352.66
# Electronics    17985.01
# Furniture      43830.44
# Sports          9452.90
# Name: Total_Sales, dtype: float64

# %% [markdown]
# # 18. What is the average discount provided per category?

# %%
df.groupby("Category")["Discount"].mean()
# Out:
# Category
# Books          6.860690
# Clothing       7.833478
# Electronics    7.293250
# Furniture      7.225824
# Sports         7.103667
# Name: Discount, dtype: float64

# %% [markdown]
# # 19. How many transactions involve 10 or more products in terms of quantity?

# %%
df.nunique()
df[df["Quantity"]>=10].shape[0]
# Out:
# 32

# %% [markdown]
# # 20. Group the data by "Payment_Method" and get the total sales for each payment method.

# %%
df.groupby("Payment_Method")["Total_Sales"].sum()
# Out:
# Payment_Method
# Cash              25850.25
# Credit Card       42128.95
# Debit Card        29972.48
# Online Payment    38150.55
# Name: Total_Sales, dtype: float64

# %% [markdown]
# # 21. Group by "Category" and find the average "Unit_Price" for each product.

# %%
df.groupby("Category")["Unit_Price"].mean()
# Out:
# Category
# Books          80.764483
# Clothing       64.829130
# Electronics    83.569000
# Furniture      91.348462
# Sports         65.085333
# Name: Unit_Price, dtype: float64

# %% [markdown]
# # 22. What is the most common discount?

# %%
df["Discount"].mode()
# Out:
# 0    6.78
# 1    6.94
# 2    7.94
# Name: Discount, dtype: float64

# %% [markdown]
# # 23. Group by "Category" and find the total sales for each category.

# %%
df.groupby("Category")["Total_Sales"].sum()
# Out:
# Category
# Books          57481.22
# Clothing        7352.66
# Electronics    17985.01
# Furniture      43830.44
# Sports          9452.90
# Name: Total_Sales, dtype: float64

# %% [markdown]
# # 24. Group by "Category" and count the number of transactions for each Category.

# %%
df.groupby("Category")["Transaction_ID"].nunique()
# Out:
# Category
# Books          116
# Clothing        23
# Electronics     40
# Furniture       91
# Sports          30
# Name: Transaction_ID, dtype: int64

# %% [markdown]
# # 25. What is the average total sales for transactions paid with credit card?

# %%
df[df["Payment_Method"]=="Credit Card"]["Total_Sales"].mean()
# Out:
# 429.88724489795925

# %% [markdown]
# # **Data Filtering and Selection**

# %% [markdown]
# # 26. How many transactions involve more than 5 products?

# %%
df[df["Quantity"]>5].shape[0]
# Out:
# 143

# %% [markdown]
# # 27. How many transactions had a discount greater than 5?

# %%
df[df["Discount"]>5].shape[0]
# Out:
# 211

# %% [markdown]
# # 28. Select all transactions where the payment method is "Debit Card."

# %%
df[df["Payment_Method"]=="Debit Card"]
# Out:
#      Transaction_ID     Transaction_Time  Product_ID     Category  Quantity  \
# 1                 2  2023-01-01 01:00:00         131       Sports         1
# 7                 8  2023-01-01 07:00:00         130    Furniture        10
# 9                10  2023-01-01 09:00:00         108    Furniture         8
# 13               14  2023-01-01 13:00:00         112    Furniture         5
# 16               17  2023-01-01 16:00:00         129       Sports         3
# ..              ...                  ...         ...          ...       ...
# 279             280  2023-01-12 15:00:00         132        Books        10
# 281             282  2023-01-12 17:00:00         142        Books         5
# 287             288  2023-01-12 23:00:00         126        Books        10
# 294             295  2023-01-13 06:00:00         144    Furniture         6
# 298             299  2023-01-13 10:00:00         132  Electronics         6
#
# ...

# %% [markdown]
# # 29. Select all transactions where the total sales exceed 100.

# %%
df[df["Total_Sales"]>100]
# Out:
#      Transaction_ID     Transaction_Time  Product_ID     Category  Quantity  \
# 3                 4  2023-01-01 03:00:00         114  Electronics         8
# 4                 5  2023-01-01 04:00:00         119  Electronics         2
# 5                 6  2023-01-01 05:00:00         128     Clothing         6
# 6                 7  2023-01-01 06:00:00         138    Furniture         7
# 8                 9  2023-01-01 08:00:00         108        Books         5
# ..              ...                  ...         ...          ...       ...
# 294             295  2023-01-13 06:00:00         144    Furniture         6
# 295             296  2023-01-13 07:00:00         134        Books         7
# 296             297  2023-01-13 08:00:00         117        Books         6
# 297             298  2023-01-13 09:00:00         132        Books         7
# 298             299  2023-01-13 10:00:00         132  Electronics         6
#
# ...

# %% [markdown]
# # 30. Find all transactions involving "Books" with a discount of 1 or more.

# %%
df[(df["Category"]=="Books") & (df["Discount"]>=1)]
# Out:
#      Transaction_ID     Transaction_Time  Product_ID Category  Quantity  \
# 8                 9  2023-01-01 08:00:00         108    Books         5
# 12               13  2023-01-01 12:00:00         119    Books         4
# 19               20  2023-01-01 19:00:00         121    Books         2
# 23               24  2023-01-01 23:00:00         113    Books         6
# 28               29  2023-01-02 04:00:00         134    Books         7
# ..              ...                  ...         ...      ...       ...
# 293             294  2023-01-13 05:00:00         138    Books         4
# 295             296  2023-01-13 07:00:00         134    Books         7
# 296             297  2023-01-13 08:00:00         117    Books         6
# 297             298  2023-01-13 09:00:00         132    Books         7
# 299             300  2023-01-13 11:00:00         139    Books         1
#
#      Unit_Price  Total_Sales  Customer_ID  Payment_Method  Discount
# ...

# %% [markdown]
# # 31. Filter the data to get transactions involving "Furniture" with a total sales value of over 100.

# %%
df[(df["Category"]=="Furniture")&(df["Total_Sales"]>100)]
# Out:
#      Transaction_ID     Transaction_Time  Product_ID   Category  Quantity  \
# 6                 7  2023-01-01 06:00:00         138  Furniture         7
# 9                10  2023-01-01 09:00:00         108  Furniture         8
# 15               16  2023-01-01 15:00:00         144  Furniture         4
# 18               19  2023-01-01 18:00:00         124  Furniture         6
# 20               21  2023-01-01 20:00:00         103  Furniture         1
# ..              ...                  ...         ...        ...       ...
# 284             285  2023-01-12 20:00:00         135  Furniture         4
# 286             287  2023-01-12 22:00:00         143  Furniture         3
# 290             291  2023-01-13 02:00:00         147  Furniture         6
# 291             292  2023-01-13 03:00:00         124  Furniture         3
# 294             295  2023-01-13 06:00:00         144  Furniture         6
#
#      Unit_Price  Total_Sales  Customer_ID  Payment_Method  Discount
# ...

# %% [markdown]
# # 32. Select all transactions where "Category" is "Electronics."

# %%
df[df["Category"]=="Electronics"]
# Out:
#      Transaction_ID     Transaction_Time  Product_ID     Category  Quantity  \
# 3                 4  2023-01-01 03:00:00         114  Electronics         8
# 4                 5  2023-01-01 04:00:00         119  Electronics         2
# 17               18  2023-01-01 17:00:00         104  Electronics         5
# 29               30  2023-01-02 05:00:00         108  Electronics         4
# 41               42  2023-01-02 17:00:00         105  Electronics         5
# 42               43  2023-01-02 18:00:00         103  Electronics         6
# 48               49  2023-01-03 00:00:00         143  Electronics         4
# 49               50  2023-01-03 01:00:00         119  Electronics         7
# 50               51  2023-01-03 02:00:00         135  Electronics         4
# 52               53  2023-01-03 04:00:00         145  Electronics         5
# 53               54  2023-01-03 05:00:00         124  Electronics         3
# ...

# %% [markdown]
# # 33. Select all transactions where the total sales is below 50.

# %%
df[df["Total_Sales"]<50]
# Out:
#     Transaction_ID     Transaction_Time  Product_ID   Category  Quantity  \
# 1                2  2023-01-01 01:00:00         131     Sports         1
# 10              11  2023-01-01 10:00:00         115  Furniture         1
# 33              34  2023-01-02 09:00:00         135      Books         3
# 40              41  2023-01-02 16:00:00         125     Sports         1
# 47              48  2023-01-02 23:00:00         131      Books         3
# 98              99  2023-01-05 02:00:00         131     Sports         4
#
#     Unit_Price  Total_Sales  Customer_ID  Payment_Method  Discount
# 1        27.58        27.58         1052      Debit Card      2.42
# 10       16.12        16.12         1047            Cash      0.00
# 33       10.01        30.03         1052      Debit Card      2.00
# 40       48.74        48.74         1064            Cash      0.00
# 47       16.34        49.02         1087  Online Payment      2.05
# ...

# %% [markdown]
# # 34. Find all transactions involving "Sports" with a unit price over 10.

# %%
df[(df["Category"]=="Sports")&(df["Unit_Price"]>10)]
# Out:
#      Transaction_ID     Transaction_Time  Product_ID Category  Quantity  \
# 1                 2  2023-01-01 01:00:00         131   Sports         1
# 2                 3  2023-01-01 02:00:00         127   Sports         1
# 11               12  2023-01-01 11:00:00         135   Sports         3
# 14               15  2023-01-01 14:00:00         118   Sports         7
# 16               17  2023-01-01 16:00:00         129   Sports         3
# 21               22  2023-01-01 21:00:00         123   Sports        10
# 24               25  2023-01-02 00:00:00         124   Sports         1
# 26               27  2023-01-02 02:00:00         140   Sports         5
# 34               35  2023-01-02 10:00:00         111   Sports         2
# 36               37  2023-01-02 12:00:00         126   Sports         1
# 37               38  2023-01-02 13:00:00         105   Sports        10
# 39               40  2023-01-02 15:00:00         121   Sports         1
# ...

# %% [markdown]
# # 35. Select all transactions where the payment method is "Online Payment."

# %%
df[df["Payment_Method"]=="Online Payment"]
# Out:
#      Transaction_ID     Transaction_Time  Product_ID     Category  Quantity  \
# 2                 3  2023-01-01 02:00:00         127       Sports         1
# 4                 5  2023-01-01 04:00:00         119  Electronics         2
# 8                 9  2023-01-01 08:00:00         108        Books         5
# 11               12  2023-01-01 11:00:00         135       Sports         3
# 18               19  2023-01-01 18:00:00         124    Furniture         6
# ..              ...                  ...         ...          ...       ...
# 286             287  2023-01-12 22:00:00         143    Furniture         3
# 288             289  2023-01-13 00:00:00         132        Books         4
# 290             291  2023-01-13 02:00:00         147    Furniture         6
# 292             293  2023-01-13 04:00:00         136        Books         5
# 295             296  2023-01-13 07:00:00         134        Books         7
#
# ...

# %% [markdown]
# # 36. How many transactions were made on January 1, 2023?

# %%
df["Transaction_Time"]=pd.to_datetime(df["Transaction_Time"])
# df.info()
df[df["Transaction_Time"].dt.date==pd.to_datetime("01-01-2023",format="%d-%m-%Y").date()]
# df.info()
# Out:
#     Transaction_ID    Transaction_Time  Product_ID     Category  Quantity  \
# 0                1 2023-01-01 00:00:00         132    Furniture         5
# 1                2 2023-01-01 01:00:00         131       Sports         1
# 2                3 2023-01-01 02:00:00         127       Sports         1
# 3                4 2023-01-01 03:00:00         114  Electronics         8
# 4                5 2023-01-01 04:00:00         119  Electronics         2
# 5                6 2023-01-01 05:00:00         128     Clothing         6
# 6                7 2023-01-01 06:00:00         138    Furniture         7
# 7                8 2023-01-01 07:00:00         130    Furniture        10
# 8                9 2023-01-01 08:00:00         108        Books         5
# 9               10 2023-01-01 09:00:00         108    Furniture         8
# 10              11 2023-01-01 10:00:00         115    Furniture         1
# 11              12 2023-01-01 11:00:00         135       Sports         3
# ...

# %%
pd.to_datetime("01-01-2023",format="%d-%m-%Y").date()
# Out:
# datetime.date(2023, 1, 1)

# %% [markdown]
# # **Sorting and Ranking**

# %% [markdown]
# # 37. Sort the transactions by "Total_Sales" in descending order.

# %%
df.sort_values(by=["Total_Sales"], ascending=False)
# Out:
#      Transaction_ID    Transaction_Time  Product_ID     Category  Quantity  \
# 249             250 2023-01-11 09:00:00         138  Electronics        10
# 287             288 2023-01-12 23:00:00         126        Books        10
# 161             162 2023-01-07 17:00:00         109        Books        10
# 225             226 2023-01-10 09:00:00         109        Books        10
# 155             156 2023-01-07 11:00:00         131        Books        10
# ..              ...                 ...         ...          ...       ...
# 40               41 2023-01-02 16:00:00         125       Sports         1
# 98               99 2023-01-05 02:00:00         131       Sports         4
# 33               34 2023-01-02 09:00:00         135        Books         3
# 1                 2 2023-01-01 01:00:00         131       Sports         1
# 10               11 2023-01-01 10:00:00         115    Furniture         1
#
#      Unit_Price  Total_Sales  Customer_ID  Payment_Method  Discount
# ...

# %% [markdown]
# # 38. Sort the transactions by "Transaction_Time."

# %%
df.sort_values(by="Transaction_Time",ascending=True)
# Out:
#      Transaction_ID    Transaction_Time  Product_ID     Category  Quantity  \
# 0                 1 2023-01-01 00:00:00         132    Furniture         5
# 1                 2 2023-01-01 01:00:00         131       Sports         1
# 2                 3 2023-01-01 02:00:00         127       Sports         1
# 3                 4 2023-01-01 03:00:00         114  Electronics         8
# 4                 5 2023-01-01 04:00:00         119  Electronics         2
# ..              ...                 ...         ...          ...       ...
# 295             296 2023-01-13 07:00:00         134        Books         7
# 296             297 2023-01-13 08:00:00         117        Books         6
# 297             298 2023-01-13 09:00:00         132        Books         7
# 298             299 2023-01-13 10:00:00         132  Electronics         6
# 299             300 2023-01-13 11:00:00         139        Books         1
#
#      Unit_Price  Total_Sales  Customer_ID  Payment_Method  Discount
# ...

# %% [markdown]
# # 39. Which transaction had the highest total sales?

# %%
df[df["Total_Sales"]==df["Total_Sales"].max()]
# Out:
#      Transaction_ID    Transaction_Time  Product_ID     Category  Quantity  \
# 249             250 2023-01-11 09:00:00         138  Electronics        10
#
#      Unit_Price  Total_Sales  Customer_ID  Payment_Method  Discount
# 249      136.62       1366.2         1020  Online Payment       7.1

# %% [markdown]
# # 40. Which transaction had the highest discount?

# %%
df[df["Discount"]==df["Discount"].max()]
# Out:
#      Transaction_ID    Transaction_Time  Product_ID     Category  Quantity  \
# 252             253 2023-01-11 12:00:00         101  Electronics         5
#
#      Unit_Price  Total_Sales  Customer_ID Payment_Method  Discount
# 252       54.72        273.6         1017    Credit Card     14.55

# %% [markdown]
# # 41. What is the first transaction in the dataset based on "Transaction_Time"?

# %%
df.sort_values(by="Transaction_Time").iloc[0]
# Out:
# Transaction_ID                        1
# Transaction_Time    2023-01-01 00:00:00
# Product_ID                          132
# Category                      Furniture
# Quantity                              5
# Unit_Price                        17.73
# Total_Sales                       88.65
# Customer_ID                        1075
# Payment_Method              Credit Card
# Discount                           2.82
# Name: 0, dtype: object

# %% [markdown]
# # 42. Which transaction had the lowest quantity sold?

# %%
df[df["Quantity"]==df["Quantity"].min()]
# Out:
#      Transaction_ID    Transaction_Time  Product_ID   Category  Quantity  \
# 1                 2 2023-01-01 01:00:00         131     Sports         1
# 2                 3 2023-01-01 02:00:00         127     Sports         1
# 10               11 2023-01-01 10:00:00         115  Furniture         1
# 20               21 2023-01-01 20:00:00         103  Furniture         1
# 24               25 2023-01-02 00:00:00         124     Sports         1
# 36               37 2023-01-02 12:00:00         126     Sports         1
# 39               40 2023-01-02 15:00:00         121     Sports         1
# 40               41 2023-01-02 16:00:00         125     Sports         1
# 43               44 2023-01-02 19:00:00         114      Books         1
# 45               46 2023-01-02 21:00:00         108   Clothing         1
# 77               78 2023-01-04 05:00:00         126  Furniture         1
# 299             300 2023-01-13 11:00:00         139      Books         1
#
# ...

# %% [markdown]
# # 43. What is the last transaction in the dataset based on "Transaction_Time"?

# %%
df.sort_values(by="Transaction_Time",ascending=False).iloc[0]
# Out:
# Transaction_ID                      300
# Transaction_Time    2023-01-13 11:00:00
# Product_ID                          139
# Category                          Books
# Quantity                              1
# Unit_Price                        51.24
# Total_Sales                       51.24
# Customer_ID                        1093
# Payment_Method                     Cash
# Discount                           6.94
# Name: 299, dtype: object

# %% [markdown]
# # 44. Sort by "Category" and find the first transaction for each category.

# %%
# df[df.sort_values(by="Category")["Category"]=="Books"].first() gives some eror
df.sort_values(by=["Category","Transaction_Time"]).groupby("Category").first()
# Out:
#              Transaction_ID    Transaction_Time  Product_ID  Quantity  \
# Category
# Books                     9 2023-01-01 08:00:00         108         5
# Clothing                  6 2023-01-01 05:00:00         128         6
# Electronics               4 2023-01-01 03:00:00         114         8
# Furniture                 1 2023-01-01 00:00:00         132         5
# Sports                    2 2023-01-01 01:00:00         131         1
#
#              Unit_Price  Total_Sales  Customer_ID  Payment_Method  Discount
# Category
# Books             38.64       193.20         1069  Online Payment      4.89
# Clothing          50.95       305.70         1015     Credit Card      6.07
# Electronics      122.07       976.56         1067     Credit Card     11.68
# Furniture         17.73        88.65         1075     Credit Card      2.82
# Sports            27.58        27.58         1052      Debit Card      2.42

# %% [markdown]
# # 45. What is the first transaction involving "Furniture"?

# %%
# df.sort_values(by="Category").groupby("Category").first().loc["Furniture"] #gives answer
# df[df["Category"]=="Furniture"].iloc[0]
# df[df.sort_values(by=["Category","Transaction_Time"])["Category"]=="Furniture"].iloc[0]
df[df["Category"]=="Furniture"].sort_values(by="Transaction_Time").iloc[0:1]
# Out:
#    Transaction_ID Transaction_Time  Product_ID   Category  Quantity  \
# 0               1       2023-01-01         132  Furniture         5
#
#    Unit_Price  Total_Sales  Customer_ID Payment_Method  Discount
# 0       17.73        88.65         1075    Credit Card      2.82

# %% [markdown]
# # 46. Sort by "Discount" and find the top 5 transactions with the highest discount.

# %%
# df.sort_values(by="Discount",ascending=False).head(5)
df.nlargest(5,"Discount")
# Out:
#      Transaction_ID    Transaction_Time  Product_ID     Category  Quantity  \
# 252             253 2023-01-11 12:00:00         101  Electronics         5
# 9                10 2023-01-01 09:00:00         108    Furniture         8
# 29               30 2023-01-02 05:00:00         108  Electronics         4
# 38               39 2023-01-02 14:00:00         130    Furniture         8
# 100             101 2023-01-05 04:00:00         101     Clothing        10
#
#      Unit_Price  Total_Sales  Customer_ID  Payment_Method  Discount
# 252       54.72       273.60         1017     Credit Card     14.55
# 9         93.45       747.60         1026      Debit Card     13.98
# 29        99.61       398.44         1039  Online Payment     13.80
# 38        94.99       759.92         1036     Credit Card     13.47
# 100       68.03       680.30         1081            Cash     13.30

# %% [markdown]
# # 47. Which transaction had the lowest unit price?

# %%
# df.sort_values(by="Unit_Price", ascending=True).head(1)
# df["Unit_Price"].idxmax()
df.iloc[df["Unit_Price"].idxmin()]
# Out:
# Transaction_ID                        8
# Transaction_Time    2023-01-01 07:00:00
# Product_ID                          130
# Category                      Furniture
# Quantity                             10
# Unit_Price                         8.17
# Total_Sales                        81.7
# Customer_ID                        1030
# Payment_Method               Debit Card
# Discount                           0.82
# Name: 7, dtype: object

# %% [markdown]
# # **Descriptive Statistics**

# %% [markdown]
# # 48. What is the mean, median, and standard deviation for "Unit_Price"?

# %%
print(df["Unit_Price"].mean())
print(df["Unit_Price"].median())
print(df["Unit_Price"].std())
# Out:
# 81.55926666666666
# 83.57
# 34.20445544129702

# %% [markdown]
# # 49. What is the range (min and max) of "Total_Sales"?

# %%
print(df["Total_Sales"].min())
print(df["Total_Sales"].max())
# Out:
# 16.12
# 1366.2

# %% [markdown]
# # 50. What is the 75th percentile for "Quantity"?

# %%
df["Quantity"].describe().loc["75%"]
df["Quantity"].quantile(0.75)
# Out:
# 7.0

# %% [markdown]
# # 51. What is the correlation between "Unit_Price" and "Total_Sales"?

# %%
df["Unit_Price"].corr(df["Total_Sales"])
# Out:
# 0.6533204141715538

# %% [markdown]
# # 52. What is the variance of "Discount"?

# %%
df["Discount"].var()
# Out:
# 10.356365886287628

# %% [markdown]
# # 53. Calculate the mean for "Total_Sales" for transactions involving "Clothing."

# %%
df[df["Category"]=="Clothing"]["Total_Sales"].mean()
# Out:
# 319.6808695652173

# %% [markdown]
# # 54. What is the median "Unit_Price" for transactions involving "Books"?

# %%
df[df["Category"]=="Books"]["Unit_Price"].median()
# Out:
# 88.315

# %% [markdown]
# # 55. What is the standard deviation of "Total_Sales" for "Electronics" transactions?

# %%
df[df["Category"]=="Electronics"]["Total_Sales"].std()
# Out:
# 272.475011651151

# %% [markdown]
# # 56. What is the standard deviation of "Quantity" for "Sports" transactions?

# %%
df[df["Category"]=="Sports"]["Quantity"].std()
# Out:
# 3.4334393466502995

# %% [markdown]
# # 57. What is the mean discount for transactions involving "Debit Card"?

# %%
df[df["Payment_Method"]=="Debit Card"]["Discount"].mean()
# Out:
# 6.273428571428571

# %% [markdown]
# # 58. What is the minimum discount given across all transactions?

# %%
df.sort_values(by="Discount").iloc[0]
# Out:
# Transaction_ID                       41
# Transaction_Time    2023-01-02 16:00:00
# Product_ID                          125
# Category                         Sports
# Quantity                              1
# Unit_Price                        48.74
# Total_Sales                       48.74
# Customer_ID                        1064
# Payment_Method                     Cash
# Discount                            0.0
# Name: 40, dtype: object

# %% [markdown]
# # 59. What is the maximum "Unit_Price" in the dataset?

# %%
df["Unit_Price"].max()
# Out:
# 146.36

# %% [markdown]
# # **Advanced Data Manipulation**

# %% [markdown]
# # 60. Create a new column "Total_Amount_After_Discount" that represents "Total_Sales" minus "Discount."

# %%
df["Total_Amount_After_Discount"]=df["Total_Sales"]-df["Discount"]
df
# Out:
#      Transaction_ID    Transaction_Time  Product_ID     Category  Quantity  \
# 0                 1 2023-01-01 00:00:00         132    Furniture         5
# 1                 2 2023-01-01 01:00:00         131       Sports         1
# 2                 3 2023-01-01 02:00:00         127       Sports         1
# 3                 4 2023-01-01 03:00:00         114  Electronics         8
# 4                 5 2023-01-01 04:00:00         119  Electronics         2
# ..              ...                 ...         ...          ...       ...
# 295             296 2023-01-13 07:00:00         134        Books         7
# 296             297 2023-01-13 08:00:00         117        Books         6
# 297             298 2023-01-13 09:00:00         132        Books         7
# 298             299 2023-01-13 10:00:00         132  Electronics         6
# 299             300 2023-01-13 11:00:00         139        Books         1
#
# ...

# %% [markdown]
# # 61. Find the number of unique customers in the dataset.

# %%
len(df["Customer_ID"].unique())
# Out:
# 96

# %% [markdown]
# # 62. Find the top 3 product categories by total sales.

# %%
df.groupby("Category")["Total_Sales"].sum().sort_values(ascending=False)[:3]
df.groupby("Category")["Total_Sales"].sum().nlargest(3)
# Out:
# Category
# Books          57481.22
# Furniture      43830.44
# Electronics    17985.01
# Name: Total_Sales, dtype: float64

# %% [markdown]
# # 66. What is the highest unit price for each product category?

# %%
df.groupby("Category")["Unit_Price"].max()
# Out:
# Category
# Books          143.86
# Clothing       112.77
# Electronics    142.36
# Furniture      146.36
# Sports         137.45
# Name: Unit_Price, dtype: float64

# %% [markdown]
# # 67. What is the average quantity of products sold per transaction for "Sports"?

# %%
df[df["Category"]=="Sports"]["Quantity"].mean()
# Out:
# 5.066666666666666

# %% [markdown]
# # 68. Create a new column "Discount_Percentage" that represents the discount as a percentage of "Total_Sales."

# %%
df["Discount_Percentage"]=(df["Discount"]/df["Total_Sales"])*100
df.head(5)
# Out:
#    Transaction_ID    Transaction_Time  Product_ID     Category  Quantity  \
# 0               1 2023-01-01 00:00:00         132    Furniture         5
# 1               2 2023-01-01 01:00:00         131       Sports         1
# 2               3 2023-01-01 02:00:00         127       Sports         1
# 3               4 2023-01-01 03:00:00         114  Electronics         8
# 4               5 2023-01-01 04:00:00         119  Electronics         2
#
#    Unit_Price  Total_Sales  Customer_ID  Payment_Method  Discount  \
# 0       17.73        88.65         1075     Credit Card      2.82
# 1       27.58        27.58         1052      Debit Card      2.42
# 2       89.11        89.11         1042  Online Payment      8.11
# 3      122.07       976.56         1067     Credit Card     11.68
# 4      122.57       245.14         1031  Online Payment     11.05
#
#    Total_Amount_After_Discount  Discount_Percentage
# 0                        85.83             3.181049
# ...

# %% [markdown]
# # 69. Calculate the average total sales for transactions made by customer IDs between 1010 and 1020.

# %%
df[(df["Customer_ID"]>1010) & (df["Customer_ID"]<1020)]["Total_Sales"].mean()
# Out:
# 595.5505263157894

# %% [markdown]
# # 70. What is the mean "Total_Sales" for transactions involving "Electronics" and paid with "Credit Card"?

# %%
df[(df["Category"]=="Electronics") & (df["Payment_Method"]=="Credit Card")]["Total_Sales"].mean()
# Out:
# 450.81733333333335

# %% [markdown]
# # **Rearranging and Indexing**

# %% [markdown]
# # 71. Retrieve all rows where the 'Category' is 'Books'.

# %%
df[df["Category"]=="Books"]
# Out:
#      Transaction_ID    Transaction_Time  Product_ID Category  Quantity  \
# 8                 9 2023-01-01 08:00:00         108    Books         5
# 12               13 2023-01-01 12:00:00         119    Books         4
# 19               20 2023-01-01 19:00:00         121    Books         2
# 23               24 2023-01-01 23:00:00         113    Books         6
# 28               29 2023-01-02 04:00:00         134    Books         7
# ..              ...                 ...         ...      ...       ...
# 293             294 2023-01-13 05:00:00         138    Books         4
# 295             296 2023-01-13 07:00:00         134    Books         7
# 296             297 2023-01-13 08:00:00         117    Books         6
# 297             298 2023-01-13 09:00:00         132    Books         7
# 299             300 2023-01-13 11:00:00         139    Books         1
#
#      Unit_Price  Total_Sales  Customer_ID  Payment_Method  Discount  \
# ...

# %% [markdown]
# #  72. Find transactions with a 'Total_Sales' greater than 500.

# %%
df[df["Total_Sales"]>500]
# Out:
#      Transaction_ID    Transaction_Time  Product_ID     Category  Quantity  \
# 3                 4 2023-01-01 03:00:00         114  Electronics         8
# 9                10 2023-01-01 09:00:00         108    Furniture         8
# 14               15 2023-01-01 14:00:00         118       Sports         7
# 22               23 2023-01-01 22:00:00         106     Clothing        10
# 27               28 2023-01-02 03:00:00         123    Furniture         5
# ..              ...                 ...         ...          ...       ...
# 289             290 2023-01-13 01:00:00         131        Books        10
# 290             291 2023-01-13 02:00:00         147    Furniture         6
# 295             296 2023-01-13 07:00:00         134        Books         7
# 296             297 2023-01-13 08:00:00         117        Books         6
# 297             298 2023-01-13 09:00:00         132        Books         7
#
# ...

# %% [markdown]
# # 73. Display last 5 transactions in the dataset.

# %%
df.sort_values(by="Transaction_Time").iloc[-1:-6:-1]
# Out:
#      Transaction_ID    Transaction_Time  Product_ID     Category  Quantity  \
# 299             300 2023-01-13 11:00:00         139        Books         1
# 298             299 2023-01-13 10:00:00         132  Electronics         6
# 297             298 2023-01-13 09:00:00         132        Books         7
# 296             297 2023-01-13 08:00:00         117        Books         6
# 295             296 2023-01-13 07:00:00         134        Books         7
#
#      Unit_Price  Total_Sales  Customer_ID  Payment_Method  Discount  \
# 299       51.24        51.24         1093            Cash      6.94
# 298       24.19       145.14         1039      Debit Card      4.95
# 297       97.13       679.91         1043     Credit Card     12.39
# 296      122.46       734.76         1059            Cash      6.57
# 295       98.82       691.74         1051  Online Payment      6.76
#
#      Total_Amount_After_Discount  Discount_Percentage
# ...

# %% [markdown]
# # 74. Display only the 'Transaction_ID', 'Category', and 'Total_Sales' columns for all rows.

# %%
df[["Transaction_ID","Category","Total_Sales"]]
# Out:
#      Transaction_ID     Category  Total_Sales
# 0                 1    Furniture        88.65
# 1                 2       Sports        27.58
# 2                 3       Sports        89.11
# 3                 4  Electronics       976.56
# 4                 5  Electronics       245.14
# ..              ...          ...          ...
# 295             296        Books       691.74
# 296             297        Books       734.76
# 297             298        Books       679.91
# 298             299  Electronics       145.14
# 299             300        Books        51.24
#
# [300 rows x 3 columns]

# %% [markdown]
# # 75. Retrieve transactions that occurred in the first 3 hours of January 1, 2023.

# %%
df[(df["Transaction_Time"]>pd.to_datetime("01-01-2023 00:00:00",format="%d-%m-%Y %H:%M:%S")) &(df["Transaction_Time"]<pd.to_datetime("01-01-2023 03:00:00",format="%d-%m-%Y %H:%M:%S"))]
# Out:
#    Transaction_ID    Transaction_Time  Product_ID Category  Quantity  \
# 1               2 2023-01-01 01:00:00         131   Sports         1
# 2               3 2023-01-01 02:00:00         127   Sports         1
#
#    Unit_Price  Total_Sales  Customer_ID  Payment_Method  Discount  \
# 1       27.58        27.58         1052      Debit Card      2.42
# 2       89.11        89.11         1042  Online Payment      8.11
#
#    Total_Amount_After_Discount  Discount_Percentage
# 1                        25.16             8.774474
# 2                        81.00             9.101111

# %%
pd.to_datetime("01-01-2023 03:00:00",format="%d-%m-%Y %H:%M:%S")
# Out:
# Timestamp('2023-01-01 03:00:00')

# %% [markdown]
# # 76. Identify the first 10 unique 'Product_IDs' in the dataset.

# %%
df["Product_ID"].unique()[:10]
# Out:
# array([132, 131, 127, 114, 119, 128, 138, 130, 108, 115], dtype=int64)

# %% [markdown]
# # 77. Find the first 10 transactions with the highest 'Quantity'.

# %%
df["Quantity"].sort_values(ascending=False)[:10]
df.sort_values(by="Quantity",ascending=False).head(10)
# Out:
#      Transaction_ID    Transaction_Time  Product_ID     Category  Quantity  \
# 161             162 2023-01-07 17:00:00         109        Books        10
# 187             188 2023-01-08 19:00:00         126    Furniture        10
# 287             288 2023-01-12 23:00:00         126        Books        10
# 249             250 2023-01-11 09:00:00         138  Electronics        10
# 37               38 2023-01-02 13:00:00         105       Sports        10
# 169             170 2023-01-08 01:00:00         139        Books        10
# 251             252 2023-01-11 11:00:00         116       Sports        10
# 279             280 2023-01-12 15:00:00         132        Books        10
# 94               95 2023-01-04 22:00:00         120        Books        10
# 253             254 2023-01-11 13:00:00         147    Furniture        10
#
#      Unit_Price  Total_Sales  Customer_ID  Payment_Method  Discount  \
# 161      126.21       1262.1         1017  Online Payment      4.65
# ...

# %% [markdown]
# # 78.  Find all transactions that occurred between 12:00 and 18:00.

# %%
df[(df["Transaction_Time"].dt.time>pd.to_datetime("12:00:00", format="%H:%M:%S").time()) & (df["Transaction_Time"].dt.time<pd.to_datetime("18:00:00", format="%H:%M:%S").time())]
# Out:
#      Transaction_ID    Transaction_Time  Product_ID     Category  Quantity  \
# 13               14 2023-01-01 13:00:00         112    Furniture         5
# 14               15 2023-01-01 14:00:00         118       Sports         7
# 15               16 2023-01-01 15:00:00         144    Furniture         4
# 16               17 2023-01-01 16:00:00         129       Sports         3
# 17               18 2023-01-01 17:00:00         104  Electronics         5
# 37               38 2023-01-02 13:00:00         105       Sports        10
# 38               39 2023-01-02 14:00:00         130    Furniture         8
# 39               40 2023-01-02 15:00:00         121       Sports         1
# 40               41 2023-01-02 16:00:00         125       Sports         1
# 41               42 2023-01-02 17:00:00         105  Electronics         5
# 61               62 2023-01-03 13:00:00         112        Books         9
# ...

# %%
pd.to_datetime("05:05:05", format="%H:%M:%S").time()
# Out:
# datetime.time(5, 5, 5)

# %% [markdown]
# # 79. Identify total quantity for all transactions made by customers with an 'ID' between 1001 and 1020.

# %%
df[(df["Customer_ID"]>1001) & (df["Customer_ID"]<1020)]["Quantity"].sum()
# Out:
# 167

# %% [markdown]
# # 80. Find count of all transactions where 'Category' is 'Furniture' and 'Discount' is less than 5.

# %%
df[(df["Category"]=="Furniture") & (df["Discount"]<5)]["Transaction_ID"].count()
# Out:
# 30

# %% [markdown]
# # 81.  List transactions where 'Quantity' is an even number.

# %%
df[df["Quantity"]%2==0]
# Out:
#      Transaction_ID    Transaction_Time  Product_ID     Category  Quantity  \
# 3                 4 2023-01-01 03:00:00         114  Electronics         8
# 4                 5 2023-01-01 04:00:00         119  Electronics         2
# 5                 6 2023-01-01 05:00:00         128     Clothing         6
# 7                 8 2023-01-01 07:00:00         130    Furniture        10
# 9                10 2023-01-01 09:00:00         108    Furniture         8
# ..              ...                 ...         ...          ...       ...
# 290             291 2023-01-13 02:00:00         147    Furniture         6
# 293             294 2023-01-13 05:00:00         138        Books         4
# 294             295 2023-01-13 06:00:00         144    Furniture         6
# 296             297 2023-01-13 08:00:00         117        Books         6
# 298             299 2023-01-13 10:00:00         132  Electronics         6
#
# ...

# %% [markdown]
# # **Data Aggregation and Advanced Grouping**

# %% [markdown]
# # 82. What is the average 'Total_Sales' by 'Category' for each day in the dataset?

# %%
df["Day"]=df["Transaction_Time"].dt.day_name()

# %%
df.groupby(["Category","Day"])["Total_Sales"].mean()
# Out:
# Category     Day
# Books        Friday       603.939412
#              Monday       392.525000
#              Saturday     673.493333
#              Sunday       464.816000
#              Thursday     579.338750
#              Tuesday      528.922000
#              Wednesday    303.110500
# Clothing     Friday       407.576667
#              Monday       201.832500
#              Saturday     407.006667
#              Sunday       551.160000
#              Thursday     412.390000
#              Tuesday      187.553333
#              Wednesday    249.000000
# Electronics  Friday       385.396000
#              Monday       466.323333
#              Saturday     528.750000
#              Sunday       384.655000
#              Thursday     508.413333
#              Tuesday      362.897778
#              Wednesday    527.642500
# Furniture    Friday       517.547500
#              Monday       400.320000
#              Saturday     617.728750
#              Sunday       470.505500
# ...

# %%
df["Transaction_Time"].dt.day_of_week

# %% [markdown]
# # 83. Find the average 'Unit_Price' for each 'Category' for the first 100 transactions.

# %%
df[:100].groupby("Category")["Unit_Price"].mean()
# df.groupby("Category")["Unit_Price"].mean()

# %% [markdown]
# # 84. Identify the customer with the highest average 'Total_Sales' across all transactions.

# %%
df.groupby("Customer_ID")["Total_Sales"].mean().nlargest(1)

# %% [markdown]
# # 85. Calculate the mean 'Total_Sales' for each 'Payment_Method'.

# %%
df.groupby("Payment_Method")["Total_Sales"].mean()

# %% [markdown]
# # 86. Group transactions by 'Product_ID' and find the transaction with the highest 'Total_Sales'.

# %%
df.groupby("Product_ID")["Total_Sales"].max().max()
df[df["Total_Sales"]==df.groupby("Product_ID")["Total_Sales"].max().max()]

# %% [markdown]
# # 87. Find the minimum 'Unit_Price' for each 'Category' and determine which 'Category' has the lowest minimum price.

# %%
df.groupby("Category")["Unit_Price"].min().idxmin()

# %% [markdown]
# # 88. Identify the 'Category' with the most transactions where 'Total_Sales' exceeds 100.

# %%
df[df["Total_Sales"]>100].groupby("Category")["Transaction_ID"].count().idxmax()

# %% [markdown]
# # 89. Determine the percentage of total 'Total_Sales' contributed by 'Credit Card' transactions.

# %%
# (df[df["Payment_Method"]=="Credit Card"].shape[0]/df.shape[0])*100
(df[df["Payment_Method"]=="Credit Card"]["Total_Sales"].sum()/df["Total_Sales"].sum())*100

# %% [markdown]
# # 90. Determine the percentage of total Quantity Sold contributed by 'Books' transactions.

# %%
(df[df["Category"]=="Books"]["Quantity"].sum()/df["Quantity"].sum())*100

# %% [markdown]
# # 91. Determine the category with the highest average 'Discount'.

# %%
df.groupby("Category")["Discount"].mean().idxmax()

# %% [markdown]
# # 92. Find the 'Customer_ID' with the highest total sales.

# %%
df.groupby("Customer_ID")["Total_Sales"].max().idxmax()

# %% [markdown]
# # 93. Count the Total_Sales for each 'Payment_Method'.

# %%
df.groupby("Payment_Method")["Total_Sales"].sum()

# %% [markdown]
# # **Columns and Structure Based Questions**

# %% [markdown]
# # 94. Add a column 'Profit' that represents 20% of 'Total_Sales'.

# %%
df["Profit"]=df["Total_Sales"]*20/100
df.head(1)

# %% [markdown]
# # 95. Create a new column 'Discounted_Price' by subtracting 'Discount' (divided by quantity) from 'Unit_Price'.

# %%
df["Discounted_Price"]=df["Unit_Price"]-df["Discount"]/df["Quantity"]
df.head(1)

# %% [markdown]
# # 96. Drop rows where 'Category' is 'Books' and 'Total_Sales' is less than 50.

# %%
df.drop(df[(df["Category"]=="Books") & (df["Total_Sales"]<50)].index)

# %% [markdown]
# # 97. Rename the 'Category' column to 'Product_Category'.

# %%
df.rename(columns={"Category":"Product_Category"},inplace=True)
df

# %% [markdown]
# # 98.  Add a column 'Is_Weekend' to indicate whether the transaction occurred on a weekend.

# %%
df["Is_Weekend"]="No"
weekend_indices = df["Transaction_Time"].dt.day_name().isin(["Saturday", "Sunday"])
df.loc[weekend_indices, "Is_Weekend"] = "Yes"
df.head()

# %% [markdown]
# # 99.  Create a new column 'High_Sales' that is True if 'Total_Sales' is above 200 and False otherwise.

# %%
df["High_Sales"]=False
df.loc[df["Total_Sales"]>200,"High_Sales"]=True
df.head(10)

# %% [markdown]
# # 100. Remove duplicate rows based on 'Product_ID'.

# %%
df.drop_duplicates(["Product_ID"])
